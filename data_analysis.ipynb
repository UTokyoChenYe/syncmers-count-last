# %%
from syncmer_count_noverlap import return_syncmer_results
import matplotlib.pyplot as plt
import pandas as pd

df = return_syncmer_results()
df.rename(columns={"mash_containment_human": "syncmer estimate of sequence identity"}, inplace=True)
df
#df.sort_values(by="blast" , inplace=True, ascending=True) 
#df.plot()
# Out:
#                                                     syncmer estimate of sequence identity  \
# Pelagia_noctiluca_mitochondrion.txt                                              0.597940
# Echinocrepis_rostrata_mitochondrion.txt                                          0.686302
# Bufo_gargarizans_mitochondrion.txt                                               0.736421
# Latimeria_menadoensis_mitochondrion.txt                                          0.752899
# Graptemys_ouachitensis_mitochondrion.txt                                         0.746822
# Trimerodytes_annularis_mitochondrion.txt                                         0.740086
# Crocodylus_porosus_mitochondrion.txt                                             0.736421
# Eudyptes_chrysolophus_mitochondrion.txt                                          0.749934
# Loxodonta_cyclotis_isolate_Coco_mitochondrion.txt                                0.767486
# Giraffa_camelopardalis_camelopardalis_isolate_G...                               0.797118
# Equus_caballus_mitochondrion.txt                                                 0.800902
# Bos_taurus_isolate_CLH_19_mitochondrion.txt                                      0.799037
# Pan_troglodytes_mitochondrion.txt                                                0.922865
# Mus_musculus_molossinus_mitochondrion.txt                                        0.790469
# Ornithorhynchus_anatinus_mitochondrion.txt                                       0.773344
# Alouatta_seniculus_mitochondrion.txt                                             0.819988
# Papio_papio_mitochondrion.txt                                                    0.825640
# Cebus_albifrons_mitochondrion.txt                                                0.814204
# Nasalis_larvatus_mitochondrion.txt                                               0.824351
# Daubentonia_madagascariensis_mitochondrion.txt                                   0.800441
# Pongo_abelii_mitochondrion.txt                                                   0.874469
# Nomascus_leucogenys_mitochondrion.txt                                            0.866522
# Gorilla_gorilla_mitochondrion.txt                                                0.905090
# Pan_paniscus_mitochondrion.txt                                                   0.923534
#
#                                                     mash_containment_none_human  \
# Pelagia_noctiluca_mitochondrion.txt                                    0.599959
# Echinocrepis_rostrata_mitochondrion.txt                                0.690188
# Bufo_gargarizans_mitochondrion.txt                                     0.734887
# Latimeria_menadoensis_mitochondrion.txt                                0.753530
# Graptemys_ouachitensis_mitochondrion.txt                               0.747326
# Trimerodytes_annularis_mitochondrion.txt                               0.739007
# Crocodylus_porosus_mitochondrion.txt                                   0.738367
# Eudyptes_chrysolophus_mitochondrion.txt                                0.750538
# Loxodonta_cyclotis_isolate_Coco_mitochondrion.txt                      0.769412
# Giraffa_camelopardalis_camelopardalis_isolate_G...                     0.798097
# Equus_caballus_mitochondrion.txt                                       0.802094
# Bos_taurus_isolate_CLH_19_mitochondrion.txt                            0.800620
# Pan_troglodytes_mitochondrion.txt                                      0.923519
# Mus_musculus_molossinus_mitochondrion.txt                              0.792191
# Ornithorhynchus_anatinus_mitochondrion.txt                             0.773617
# Alouatta_seniculus_mitochondrion.txt                                   0.820808
# Papio_papio_mitochondrion.txt                                          0.827275
# Cebus_albifrons_mitochondrion.txt                                      0.815071
# Nasalis_larvatus_mitochondrion.txt                                     0.825069
# Daubentonia_madagascariensis_mitochondrion.txt                         0.802343
# Pongo_abelii_mitochondrion.txt                                         0.875770
# Nomascus_leucogenys_mitochondrion.txt                                  0.868124
# Gorilla_gorilla_mitochondrion.txt                                      0.905789
# Pan_paniscus_mitochondrion.txt                                         0.924337
#
#                                                      blast
# Pelagia_noctiluca_mitochondrion.txt                 0.6715
# Echinocrepis_rostrata_mitochondrion.txt             0.7123
# Bufo_gargarizans_mitochondrion.txt                  0.7044
# Latimeria_menadoensis_mitochondrion.txt             0.6893
# Graptemys_ouachitensis_mitochondrion.txt            0.7016
# Trimerodytes_annularis_mitochondrion.txt            0.6962
# Crocodylus_porosus_mitochondrion.txt                0.7067
# Eudyptes_chrysolophus_mitochondrion.txt             0.6931
# Loxodonta_cyclotis_isolate_Coco_mitochondrion.txt   0.7277
# Giraffa_camelopardalis_camelopardalis_isolate_G...  0.7405
# Equus_caballus_mitochondrion.txt                    0.7501
# Bos_taurus_isolate_CLH_19_mitochondrion.txt         0.7434
# Pan_troglodytes_mitochondrion.txt                   0.9138
# Mus_musculus_molossinus_mitochondrion.txt           0.7222
# Ornithorhynchus_anatinus_mitochondrion.txt          0.6912
# Alouatta_seniculus_mitochondrion.txt                0.7922
# Papio_papio_mitochondrion.txt                       0.7923
# Cebus_albifrons_mitochondrion.txt                   0.7931
# Nasalis_larvatus_mitochondrion.txt                  0.7935
# Daubentonia_madagascariensis_mitochondrion.txt      0.7523
# Pongo_abelii_mitochondrion.txt                      0.8563
# Nomascus_leucogenys_mitochondrion.txt               0.8433
# Gorilla_gorilla_mitochondrion.txt                   0.8955
# Pan_paniscus_mitochondrion.txt                      0.9150

# %%
df.sort_values(by="blast" , inplace=True, ascending=True) 
df.plot(kind='scatter', x='syncmer estimate of sequence identity', y='blast', c='r', title="Blast ANI vs Syncmers ANI")
# Out:
# <Axes: title={'center': 'Blast ANI vs Syncmers ANI'}, xlabel='syncmer estimate of sequence identity', ylabel='blast'>

# %%
df.plot(kind='scatter', x='syncmer estimate of sequence identity', y='blast', c='r',xlim=(0,1), ylim=(0,1),title="Blast ANI vs Syncmers ANI (zoom (0,1))")
# Out:
# <Axes: title={'center': 'Blast ANI vs Syncmers ANI (zoom (0,1))'}, xlabel='syncmer estimate of sequence identity', ylabel='blast'>

# %%
df = df.reset_index()
df.rename(columns={"index": "latin_name"}, inplace=True)

# %%
df
# Out:
#                                            Latin_name  \
# 0                 Pelagia_noctiluca_mitochondrion.txt
# 1             Latimeria_menadoensis_mitochondrion.txt
# 2          Ornithorhynchus_anatinus_mitochondrion.txt
# 3             Eudyptes_chrysolophus_mitochondrion.txt
# 4            Trimerodytes_annularis_mitochondrion.txt
# 5            Graptemys_ouachitensis_mitochondrion.txt
# 6                  Bufo_gargarizans_mitochondrion.txt
# 7                Crocodylus_porosus_mitochondrion.txt
# 8             Echinocrepis_rostrata_mitochondrion.txt
# 9           Mus_musculus_molossinus_mitochondrion.txt
# 10  Loxodonta_cyclotis_isolate_Coco_mitochondrion.txt
# 11  Giraffa_camelopardalis_camelopardalis_isolate_...
# 12        Bos_taurus_isolate_CLH_19_mitochondrion.txt
# 13                   Equus_caballus_mitochondrion.txt
# 14     Daubentonia_madagascariensis_mitochondrion.txt
# 15               Alouatta_seniculus_mitochondrion.txt
# 16                      Papio_papio_mitochondrion.txt
# 17                  Cebus_albifrons_mitochondrion.txt
# 18                 Nasalis_larvatus_mitochondrion.txt
# 19              Nomascus_leucogenys_mitochondrion.txt
# 20                     Pongo_abelii_mitochondrion.txt
# 21                  Gorilla_gorilla_mitochondrion.txt
# 22                  Pan_troglodytes_mitochondrion.txt
# 23                     Pan_paniscus_mitochondrion.txt
#
#     syncmer estimate of sequence identity  mash_containment_none_human   blast
# 0                                0.597940                     0.599959  0.6715
# 1                                0.752899                     0.753530  0.6893
# 2                                0.773344                     0.773617  0.6912
# 3                                0.749934                     0.750538  0.6931
# 4                                0.740086                     0.739007  0.6962
# 5                                0.746822                     0.747326  0.7016
# 6                                0.736421                     0.734887  0.7044
# 7                                0.736421                     0.738367  0.7067
# 8                                0.686302                     0.690188  0.7123
# 9                                0.790469                     0.792191  0.7222
# 10                               0.767486                     0.769412  0.7277
# 11                               0.797118                     0.798097  0.7405
# 12                               0.799037                     0.800620  0.7434
# 13                               0.800902                     0.802094  0.7501
# 14                               0.800441                     0.802343  0.7523
# 15                               0.819988                     0.820808  0.7922
# 16                               0.825640                     0.827275  0.7923
# 17                               0.814204                     0.815071  0.7931
# 18                               0.824351                     0.825069  0.7935
# 19                               0.866522                     0.868124  0.8433
# 20                               0.874469                     0.875770  0.8563
# 21                               0.905090                     0.905789  0.8955
# 22                               0.922865                     0.923519  0.9138
# 23                               0.923534                     0.924337  0.9150

# %%
df.plot(y=["syncmer estimate of sequence identity","blast"], rot=60, figsize=(10, 6)).set_ylabel("ANI")
# Out:
# Text(0, 0.5, 'ANI')
